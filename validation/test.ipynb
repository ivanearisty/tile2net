# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Change the path to whichever year you want to see
shp_path = "../output/bk_central_2022/bk_central_2022/polygons/bk_central_2022-Polygons-01-12-2025_09_19/bk_central_2022-Polygons-01-12-2025_09_19.shp"

gdf = gpd.read_file(shp_path)
gdf.plot(figsize=(8, 8))
plt.tight_layout()
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Change the path to whichever year you want to see
shp_path = "../output/bk_central_2018/bk_central_2018/polygons/bk_central_2018-Polygons-01-12-2025_03_15/bk_central_2018-Polygons-01-12-2025_03_15.dbf"

gdf = gpd.read_file(shp_path)
gdf.plot(figsize=(8, 8))
plt.tight_layout()
plt.show()
